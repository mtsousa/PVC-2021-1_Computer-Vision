# %% [markdown]
# ## Initial steps
#
# * Mount the Google Drive
# * Check the dependencies
# * Downgrade Tensorflow and Keras
# * Opencv - Tensorflow API [link][]
#
# [link]: https://github.com/opencv/opencv/wiki/TensorFlow-Object-Detection-API

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load weights
#
# * Mantain all files
# * Import configurations in "inference" mode as train_model.py

# %% [markdown]
# ## Frozen graph
#
# * Export .pb file with frozen graph
# * Use Tensorflow to load and read the graph
